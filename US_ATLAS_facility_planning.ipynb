# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaellopesdesa/FacilitiesSummary2025/blob/master/US_ATLAS_facility_planning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
from google.auth import default
import gspread
from google.colab import sheets

auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# %%
import sys, time
sys.path.append('drive/MyDrive/Facilities/Planning')
from utils import *

# %%
# Uncomment this if you want to see the google sheet here, what can be useful during development
#sheets.InteractiveSheet(title='US ATLAS Facility Planning')

# %%
spreadsheet = gc.open('US ATLAS Facility Planning')

# %%
info_net2 = optimize(spreadsheet, ['NET2'], ['NET2 output'])
makeSummary(info_net2, ['NET2'], ['regular funding', 'no FY26/27 equipment'], 'NET2.png')
time.sleep(30) #not to overload google sheets with requets

# %%
info_aglt2 = optimize(spreadsheet, ['AGLT2'], ['AGLT2 output'])
makeSummary(info_aglt2, ['AGLT2'], ['regular funding', 'no FY26/27 equipment'], 'AGLT2.png')
time.sleep(30)

# %%
info_swt2 = optimize(spreadsheet, ['SWT2'], ['SWT2 output'])
makeSummary(info_swt2, ['SWT2'], ['regular funding', 'no FY26/27 equipment'], 'SWT2.png')
time.sleep(30)

# %%
info_mwt2 = optimize(spreadsheet, ['MWT2'], ['MWT2 output'])
makeSummary(info_mwt2, ['MWT2'], ['regular funding', 'no FY26/27 equipment'], 'MWT2.png')
time.sleep(30)

# %%
# !cd /content/drive/MyDrive/Facilities/Planning/summary/; cp ../*.py .; git add .; git commit -m"update"; git push origin master
# Out:
# On branch master
# nothing to commit, working tree clean
# Everything up-to-date
